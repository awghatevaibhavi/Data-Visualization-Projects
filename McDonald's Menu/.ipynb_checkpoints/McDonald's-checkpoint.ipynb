# %%
import pandas as pd
import plotly.offline as po
po.init_notebook_mode(connected=True)
import plotly.plotly as py
import plotly.graph_objs as go
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
#reading file
df = pd.read_csv("/Users/vaibhaviawghate/Documents/Data Projects/McDonald's Menu/menu.csv")
df.head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)       300
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)       250
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)       370
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)       450
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)       400
#
#    Calories from Fat  Total Fat  Total Fat (% Daily Value)  Saturated Fat  \
# 0                120       13.0                         20            5.0
# 1                 70        8.0                         12            3.0
# 2                200       23.0                         35            8.0
# 3                250       28.0                         43           10.0
# 4                210       23.0                         35            8.0
#
#    Saturated Fat (% Daily Value)  Trans Fat          ...           \
# ...

# %%
f, axes = plt.subplots(2, 2, figsize=(25,12))
sns.factorplot(x="Category", y="Cholesterol (% Daily Value)", data=df, kind="swarm", ax = axes[0,0])
sns.factorplot(x="Category", y="Carbohydrates", data=df, kind="swarm", ax = axes[0,1])
sns.factorplot(x="Category", y="Protein", data=df, kind="swarm", ax = axes[1,0])
sns.factorplot(x="Category", y="Total Fat", data=df, kind="swarm", ax = axes[1,1])
plt.setp(axes, yticks=[])
f.tight_layout()
plt.close(5)
plt.close(4)
plt.close(3)
plt.close(2)

# %%
trace = go.Scatter(
    y = df['Cholesterol (% Daily Value)'].values,
    x = df['Item'].values,
    mode='markers',
    marker=dict(
        size= df['Cholesterol (% Daily Value)'].values,
        color = df['Cholesterol (% Daily Value)'].values,
        colorscale='Portland',
        showscale=True
    ),
)
data = [trace]

layout= go.Layout(
    autosize= True,
    title= 'Cholesterol (% Daily Value) per Item on the Menu',
    xaxis=dict(
        showgrid=False,
        zeroline=False,
        showline=False
    ),
    yaxis=dict(
        title= 'Cholesterol (% Daily Value)',
        ticklen= 5,
        gridwidth= 2,
        showgrid=False,
        zeroline=False,
        showline=False
    ),
    showlegend= False,
    hovermode = 'closest'
)
fig = go.Figure(data=data, layout=layout)
py.iplot(fig,filename='scatterChol')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~vna4493/60.embed" height="525px" width="100%"></iframe>

# %%
trace = go.Scatter(
    y = df['Carbohydrates'].values,
    x = df['Item'].values,
    mode='markers',
    marker=dict(
        size= df['Carbohydrates'].values,
        color = df['Carbohydrates'].values,
        colorscale='Portland',
        showscale=True
    ),
)
data = [trace]

layout= go.Layout(
    autosize= True,
    title= 'Carbohydrates per Item',
    xaxis=dict(
        showgrid=False,
        zeroline=False,
        showline=False
    ),
    yaxis=dict(
        title= 'Carbohydrates',
        ticklen= 5,
        gridwidth= 2,
        showgrid=False,
        zeroline=False,
        showline=False
    ),
    showlegend= False,
    hovermode = 'closest'
)
fig = go.Figure(data=data, layout=layout)
py.iplot(fig,filename='scatterChol')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~vna4493/60.embed" height="525px" width="100%"></iframe>

# %%
trace = go.Scatter(
    y = df['Protein'].values,
    x = df['Item'].values,
    mode='markers',
    marker=dict(
        size= df['Protein'].values,
        color = df['Protein'].values,
        colorscale='Portland',
        showscale=True
    ),
)
data = [trace]

layout= go.Layout(
    autosize= True,
    title= 'Protein per Item',
    xaxis=dict(
        showgrid=False,
        #zeroline=False,
        #showline=False
    ),
    yaxis=dict(
        title= 'Protein',
        ticklen= 5,
        gridwidth= 2,
        showgrid=False,
        #zeroline=False,
        #showline=False
    ),
    showlegend= False,
    hovermode = 'closest'
)
fig = go.Figure(data=data, layout=layout)
py.iplot(fig,filename='scatterChol')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~vna4493/60.embed" height="525px" width="100%"></iframe>

# %%
trace = go.Scatter(
    y = df['Total Fat'].values,
    x = df['Item'].values,
    mode='markers',
    marker=dict(
        size= df['Total Fat'].values,
        color = df['Total Fat'].values,
        colorscale='Portland',
        showscale=True
    ),
)
data = [trace]

layout= go.Layout(
    autosize= True,
    title= 'Total Fats per Item',
    xaxis=dict(
        showgrid=False,
        #zeroline=False,
        #showline=False
    ),
    yaxis=dict(
        title= 'Total Fats',
        ticklen= 5,
        gridwidth= 2,
        showgrid=False,
        #zeroline=False,
        #showline=False
    ),
    showlegend= False,
    hovermode = 'closest'
)
fig = go.Figure(data=data, layout=layout)
py.iplot(fig,filename='scatterChol')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~vna4493/60.embed" height="525px" width="100%"></iframe>
